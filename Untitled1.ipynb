# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("max_row", None) # 행 수 제한 해제
pd.set_option("max_column", None) # 열 수 제한 해제
# %matplotlib inline

# %%
rawData = pd.read_csv('data/asos_90_20120603_20220602.csv')

rawData.tail(3)
# Out:
#       Unnamed: 0  stnId stnNm          tm  avgTa  minTa  minTaHrmt  maxTa  \
# 3649        3649     90    속초  2022-05-31   20.9   12.8        323   26.8
# 3650        3650     90    속초  2022-06-01   20.7   16.3       2334   24.2
# 3651        3651     90    속초  2022-06-02   21.3   16.1        419   27.2
#
#       maxTaHrmt  mi10MaxRn  mi10MaxRnHrmt  hr1MaxRn  hr1MaxRnHrmt  sumRnDur  \
# 3649       1820        NaN            NaN       NaN           NaN       NaN
# 3650        923        NaN            NaN       NaN           NaN       NaN
# 3651       1156        NaN            NaN       NaN           NaN       NaN
#
#       sumRn  maxInsWs  maxInsWsWd  maxInsWsHrmt  maxWs  maxWsWd  maxWsHrmt  \
# 3649    NaN      10.4         270          1909    6.1      140       1527
# 3650    NaN       8.9         270           213    3.8      360       1110
# 3651    NaN       7.6         140          1312    4.6      140       1247
#
#       avgWs  hr24SumRws  maxWd  avgTd  minRhm  minRhmHrmt  avgRhm  avgPv  \
# 3649    2.1        1854  290.0    8.5    17.0      2341.0    51.3   11.9
# 3650    1.7        1473   20.0    7.2    16.0        28.0    44.4   10.8
# 3651    1.8        1534  140.0   11.8    28.0       947.0    57.0   14.0
#
#        avgPa   maxPs  maxPsHrmt   minPs  minPsHrmt   avgPs  ssDur  sumSsHr  \
# 3649  1003.4  1007.5       1220  1003.8          1  1005.4   14.6     12.7
# 3650  1002.8  1008.1        420  1002.4       1738  1004.8   14.7      9.2
# 3651  1003.4  1008.0       2357  1003.9          1  1005.4   14.7     13.2
#
#       hr1MaxIcsrHrmt  hr1MaxIcsr  sumGsr  ddMefs  ddMefsHrmt  ddMes  \
# 3649             NaN         NaN     NaN     NaN         NaN    NaN
# 3650             NaN         NaN     NaN     NaN         NaN    NaN
# 3651             NaN         NaN     NaN     NaN         NaN    NaN
#
#       ddMesHrmt  sumDpthFhsc  avgTca  avgLmac  avgTs  minTg  avgCm5Te  \
# 3649        NaN          NaN     2.3      0.6   28.4    8.5       NaN
# 3650        NaN          NaN     4.5      1.8   28.8   12.3       NaN
# 3651        NaN          NaN     2.3      0.0   30.9   10.3       NaN
#
#       avgCm10Te  avgCm20Te  avgCm30Te  avgM05Te  avgM10Te  avgM15Te  avgM30Te  \
# 3649        NaN        NaN        NaN       NaN       NaN       NaN       NaN
# 3650        NaN        NaN        NaN       NaN       NaN       NaN       NaN
# 3651        NaN        NaN        NaN       NaN       NaN       NaN       NaN
#
#       avgM50Te  sumLrgEv  sumSmlEv  n99Rn iscs  sumFogDur
# 3649       NaN       NaN       NaN    NaN  NaN        NaN
# 3650       NaN       NaN       NaN    NaN  NaN        NaN
# 3651       NaN       NaN       NaN    NaN  NaN        NaN

# %%
rawData['ddMefs'].count()
# Out:
# 45
