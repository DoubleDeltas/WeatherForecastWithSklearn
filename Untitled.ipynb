# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("max_row", None) # 행 수 제한 해제
pd.set_option("max_column", None) # 열 수 제한 해제
# %matplotlib inline

# %% [markdown]
# # Load Data

# %%
rawData = pd.read_csv('data/asos_253_20120603_20220602.csv')

rawData.tail(3)
# Out:
#       Unnamed: 0  stnId stnNm          tm  avgTa  minTa  minTaHrmt  maxTa  \
# 3649        3649    253   김해시  2022-05-31   22.6   18.2        603   29.1
# 3650        3650    253   김해시  2022-06-01   22.2   17.5        512   29.5
# 3651        3651    253   김해시  2022-06-02   21.8   16.6        544   27.7
#
#       maxTaHrmt  mi10MaxRn  mi10MaxRnHrmt  hr1MaxRn  hr1MaxRnHrmt  sumRnDur  \
# 3649       1303        NaN            NaN       NaN           NaN       NaN
# 3650       1145        NaN            NaN       NaN           NaN       NaN
# 3651       1328        NaN            NaN       NaN           NaN       NaN
#
#       sumRn  maxInsWs  maxInsWsWd  maxInsWsHrmt  maxWs  maxWsWd  maxWsHrmt  \
# 3649    NaN      10.9         160          1637    6.9      160       1636
# 3650    NaN       8.1         180          1342    4.8      160       1607
# 3651    NaN       8.2         160          1454    5.4      160       1452
#
# ...

# %% [markdown]
# ## Check Missing Values

# %%
rawData.isna().sum()
# Out:
# Unnamed: 0           0
# stnId                0
# stnNm                0
# tm                   0
# avgTa                7
# minTa                0
# minTaHrmt            0
# maxTa                0
# maxTaHrmt            0
# mi10MaxRn         2886
# mi10MaxRnHrmt     3059
# hr1MaxRn          2884
# hr1MaxRnHrmt      3036
# sumRnDur          3650
# sumRn             2551
# maxInsWs             0
# maxInsWsWd           0
# maxInsWsHrmt         0
# maxWs                0
# maxWsWd              0
# maxWsHrmt            0
# avgWs                0
# hr24SumRws           0
# maxWd               12
# avgTd                8
# minRhm               0
# minRhmHrmt           0
# avgRhm               7
# avgPv                8
# avgPa               11
# maxPs                4
# maxPsHrmt            4
# minPs                5
# minPsHrmt            4
# avgPs               12
# ssDur                0
# sumSsHr             17
# hr1MaxIcsrHrmt       2
# hr1MaxIcsr           2
# sumGsr               5
# ...

# %%
data1 = pd.DataFrame(rawData)

data1.drop(['Unnamed: 0', 'stnId', 'stnNm'], axis=1, inplace=True)

# Missing avgTa <- avg. of minTa and maxTa
data1['avgTa'].fillna((data1['minTa'] + data1['maxTa'] / 2), inplace=True)

data1.isna().sum()
# Out:
# tm                   0
# avgTa                0
# minTa                0
# minTaHrmt            0
# maxTa                0
# maxTaHrmt            0
# mi10MaxRn         2886
# mi10MaxRnHrmt     3059
# hr1MaxRn          2884
# hr1MaxRnHrmt      3036
# sumRnDur          3650
# sumRn             2551
# maxInsWs             0
# maxInsWsWd           0
# maxInsWsHrmt         0
# maxWs                0
# maxWsWd              0
# maxWsHrmt            0
# avgWs                0
# hr24SumRws           0
# maxWd               12
# avgTd                8
# minRhm               0
# minRhmHrmt           0
# avgRhm               7
# avgPv                8
# avgPa               11
# maxPs                4
# maxPsHrmt            4
# minPs                5
# minPsHrmt            4
# avgPs               12
# ssDur                0
# sumSsHr             17
# hr1MaxIcsrHrmt       2
# hr1MaxIcsr           2
# sumGsr               5
# ddMefs            3651
# ddMefsHrmt        3651
# ddMes             3650
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3652 entries, 0 to 3651
# Data columns (total 60 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tm              3652 non-null   object
#  1   avgTa           3652 non-null   float64
#  2   minTa           3652 non-null   float64
#  3   minTaHrmt       3652 non-null   int64
#  4   maxTa           3652 non-null   float64
#  5   maxTaHrmt       3652 non-null   int64
#  6   mi10MaxRn       766 non-null    float64
#  7   mi10MaxRnHrmt   593 non-null    float64
#  8   hr1MaxRn        768 non-null    float64
#  9   hr1MaxRnHrmt    616 non-null    float64
#  10  sumRnDur        2 non-null      float64
#  11  sumRn           1101 non-null   float64
#  12  maxInsWs        3652 non-null   float64
#  13  maxInsWsWd      3652 non-null   int64
#  14  maxInsWsHrmt    3652 non-null   int64
#  15  maxWs           3652 non-null   float64
#  16  maxWsWd         3652 non-null   int64
# ...
